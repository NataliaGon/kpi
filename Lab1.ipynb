# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaGon/kpi/blob/math-models/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import freqs
from scipy.optimize import brentq

# %% [markdown]
# # Фігури Лісажу

# %%
#Функція для малювання кривої Ліссажу
def lissajous(a, b, delta, tmax=2*np.pi, n=1000):
    t = np.linspace(0, tmax, n)
    x = np.sin(a*t + delta)
    y = np.sin(b*t)
    return x, y

    # a - частота першого сигналу (по осі x), відповідає ω1
    # b - частота другого сигналу (по осі y), відповідає ω2
    # delta - зсув по фазі між x та y
    # tmax - максимальне значення часу t тобто як довго «спостерігаємо» сигнал (2 pi)
    # n - кількість точок дискретизації (чим більше, тим плавніша крива).


# Ранг-1 (ω1/ω2 = 1), різні фази ω - частоти
phases = [0, np.pi/6, np.pi/4, np.pi/2]
plt.figure(figsize=(10,8))
for i, d in enumerate(phases, 1):
    x, y = lissajous(1, 1, d)
    plt.subplot(2,2,i)
    plt.plot(x,y)
    plt.title(f" Ранг-1: Δ={d:.2f} радіан")
    plt.axis('equal')
    plt.axis('off')
plt.show()

# Майже рівні частоти (≈1)
x, y = lissajous(1, 1.05, 200*np.pi)  # long time
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.title("Майже рівні ω1/ω2 ≈ 1")
plt.axis('equal')
plt.axis('off')
plt.show()

# Ранг-2 (ω1/ω2 = 2), різні фази
phases = [0, np.pi/6, np.pi/4, np.pi/2]
plt.figure(figsize=(10,8))
for i, d in enumerate(phases, 1):
    x, y = lissajous(2, 1, d)
    plt.subplot(2,2,i)
    plt.plot(x,y)
    plt.title(f" Ранг-2: Δ={d:.2f} радіан")
    plt.axis('equal')
    plt.axis('off')
plt.show()

# %%
# 4) Поліном Чебишева (оберіть n у [3..7])

def Tn(x, n):
    return np.cos(n*np.arccos(x))

n = 5
x = np.linspace(-1, 1, 1000)
y = Tn(x, n)

plt.figure(figsize=(6,5))
plt.plot(x, y, linewidth=2)
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.title(f"Поліном Чебишева Tₙ(x), n = {n}")
plt.xlabel("x"); plt.ylabel("Tₙ(x)")
plt.grid(True, alpha=0.25)
plt.show()

# %% [markdown]
# У ході виконання роботи було досліджено особливості побудови фігур Ліссажу та поліномів Чебишева, а також проаналізовано їх взаємозв’язок.
#
# **Фігури Ліссажу.**
#
# При відношенні частот
# 𝜔1/𝜔2=1 форма кривої визначається різницею фаз
# Δ: при Δ=0
#  отримуємо пряму лінію
# y=x, при малих
#
# Δ – еліпс, а при Δ=0∘
# Δ=90∘
#  – коло (за рівності амплітуд). Подальше зростання різниці фаз призводить до обертання та деформації еліпса.
#
# При відношенні
# 𝜔1/𝜔2≈1 фігура не замикається, а траєкторія поступово заповнює певну площу, утворюючи квазіперіодичний візерунок.
#
# При відношенні
# 𝜔1/𝜔2=2 формуються замкнені багатопелюсткові криві. Зміна різниці фаз впливає на їх орієнтацію та характер перетинів.
#
# **Поліноми Чебишева.**
#
# Поліном Чебишева Tn(x) визначається співвідношенням: Tn(x) = cos(n · arccos(x)). Його графік завжди лежить у межах від –1 до 1 і має рівно n нулів.
# Візуально графік нагадує синусоїдальну хвилю, стиснуту на відрізку [–1; 1].
#
# Існує прямий зв’язок між фігурами Ліссажу та поліномами Чебишева: при параметризації x = cos(t) отримаємо y = Tn(x) = cos(nt), що відповідає кривій Ліссажу з відношенням частот n:1.
#
#
# Отримані результати демонструють, що фігури Ліссажу відображають геометричні властивості гармонічних коливань у площині, тоді як поліноми Чебишева є функціональним представленням тих самих коливальних процесів у вигляді ортогональних поліномів. Таким чином, обидва підходи описують єдину фізичну природу гармонічних процесів різними математичними методами — параметричними рівняннями та поліноміальними функціями.

# %% [markdown]
# # Годограф Михайлова

# %%
# Варіант 1: Явна функція

def Djw(w):
    jw = 1j*w
    return jw**99 + jw**88 + jw**77 + jw**5 + jw + 4

w = np.logspace(-3, 3, 5000)
Z = Djw(w)

# Годограф
plt.plot(Z.real, Z.imag)
plt.scatter([4],[0], s=20)           # старт у точці 4+0j
plt.axhline(0, linewidth=0.8)
plt.axvline(0, linewidth=0.8)
plt.axis('equal'); plt.title('Годограф Михайлова для D(jω)')
plt.xlabel('Re'); plt.ylabel('Im'); plt.show()

# Зміна аргумента
angles = np.unwrap(np.angle(Z))
print('Δarg ≈', angles[-1]-angles[0], 'рад')
# Out:
# Δarg ≈ -1.5710463267896886 рад

# %%
# Варіант 2: Масив коефіцієнтів

# D(p) = p^99 + p^88 + p^77 + p^5 + p + 4

# Коефіцієнти поліноміів від найвищого степеня до константи:
den = np.zeros(100)           # length = max power + 1
den[0]  = 1                   # p^99
den[99-88] = 1                # p^88
den[99-77] = 1                # p^77
den[99-5]  = 1                # p^5
den[99-1]  = 1                # p^1
den[-1]    = 4                # constant

# Обчисліть D(jw): використовуйте частоти з чисельником=den та знаменником=[1]
w = np.logspace(-3, 3, 5000)
wjw, Djw = freqs(b=den, a=[1], worN=w)   # Djw = D(jw)

# Mikhailov plot
plt.plot(Djw.real, Djw.imag)
plt.scatter([4],[0], s=20)     # start at D(0)=4
plt.axhline(0, linewidth=0.8)
plt.axvline(0, linewidth=0.8)
plt.axis('equal'); plt.title('Годограф Михайлова для D(jω)')
plt.xlabel('Re'); plt.ylabel('Im'); plt.show()

# Зміна аргументу (для підрахунку полюсів RHP)
angles = np.unwrap(np.angle(Djw))
print("Δarg ≈", angles[-1]-angles[0], "rad")
# Out:
# Δarg ≈ -1.5710463267896886 rad

# %% [markdown]
# Для даного характеристичного полінома D(p)=p^99+p^88+p^77+p^5+p+4 зміна аргумента arg D(jω) при ω:0→∞ становить −π/2, тоді як для стійкої системи порядку n=99 необхідно, щоб ця зміна дорівнювала 99π/2. Отже, умова критерію Михайлова не виконується. Система є нестійкою, оскільки годограф не проходить послідовно всі квадранти проти годинникової стрілки, а натомість зміщується лише на одну чверть у протилежному напрямку.

# %% [markdown]
# # Банкомат

# %%
import random
from typing import Tuple, Dict, List


def hrn_kop_to_str(cents: int) -> str:
    sign = "-" if cents < 0 else ""
    cents = abs(cents)
    hrn, kop = divmod(cents, 100)
    return f"{sign}{hrn}.{kop:02d} грн"

def parse_amount(user_input: str) -> int:
    """
    Приймає рядок на кшталт "120", "120.50", "120,50" -> повертає копійки (int).
    Підійде і для цілих гривень, і для гривень з копійками.
    """
    s = user_input.strip().replace(",", ".")
    if "." in s:
        hrn_str, kop_str = s.split(".", 1)
        hrn = int(hrn_str) if hrn_str else 0
        kop = int((kop_str + "00")[:2])
    else:
        hrn, kop = int(s), 0
    return hrn * 100 + kop

def breakdown_banknotes(amount_cents: int) -> Dict[str, int]:
    """
    Повертає розбиття суми за номіналами (опціонально для a8).
    Номінали: 1000, 500, 200, 100, 50, 20, 10 грн; монети 5, 2, 1 грн; 50, 25, 10, 5 коп.
    """
    remaining = amount_cents
    denoms = [100000, 50000, 20000, 10000, 5000, 2000, 1000, 500, 200, 100, 50, 25, 10, 5]
    names  = ["1000 грн","500 грн","200 грн","100 грн","50 грн","20 грн","10 грн",
              "5 грн","2 грн","1 грн","50 коп","25 коп","10 коп","5 коп"]
    out = {}
    for d, name in zip(denoms, names):
        if remaining <= 0:
            break
        cnt, remaining = divmod(remaining, d)
        if cnt:
            out[name] = cnt
    return out


SUPPORTED_CARD_TYPES = {1, 2}
ALLOWED_CODES = {1234, 4321, 2580}
MAX_PIN_TRIES = 3

def a0_insert_card() -> None:
    print("a0: Будь ласка, вставте картку (введіть тип картки цілим числом).")

def a1_recognize_card(card_type: int) -> bool:
    if card_type not in SUPPORTED_CARD_TYPES:
        print("a13: Тип картки не підтримується цим банкоматом. Картку повернуто.")
        return False
    print("a1: Картку розпізнано.")
    return True

def a2_prompt_pin() -> None:
    print("a2: Введіть PIN-код (ціле число).")

def a3_check_pin(pin: int, tries_left: int) -> Tuple[bool, int]:
    if pin in ALLOWED_CODES:
        print("a3: Код вірний.")
        return True, tries_left
    tries_left -= 1
    if tries_left > 0:
        print(f"a11: Невірний код. Спробуйте ще раз. Залишилось спроб: {tries_left}")
    else:
        print("a12: Невірний код. Картку заблоковано.")
    return False, tries_left

def a4_menu() -> str:
    print("\n=== a4: Меню ===")
    print("1) Стан рахунку")
    print("2) Зняття готівки")
    print("3) Вихід")
    return input("Оберіть операцію (1/2/3): ").strip()

def a5_show_balance(balance: int) -> None:
    print(f"a5: Стан рахунку: {hrn_kop_to_str(balance)}")

def a6_ask_amount() -> int:
    s = input("a6: Введіть суму для зняття (грн або грн.коп): ")
    return parse_amount(s)

def a7_has_funds(balance: int, amount: int) -> bool:
    return balance >= amount

def a8_dispense_cash(balance: int, amount: int) -> int:
    print(f"a8: Видано готівку: {hrn_kop_to_str(amount)}")
    parts = breakdown_banknotes(amount)
    if parts:
        pretty = ", ".join(f"{k} × {v}" for k, v in parts.items())
        print(f"   Номінали: {pretty}")
    balance -= amount
    print(f"   Новий баланс: {hrn_kop_to_str(balance)}")
    return balance

def a9_insufficient() -> None:
    print("a9: Недостатньо коштів на рахунку. Повернення до меню.")

def a10_goodbye() -> None:
    print("a10: Дякуємо! Гарного дня. Картку повернуто.\n")


def main():
    initial_hrn = random.randint(0, 20000)
    initial_kop = random.randint(0, 99)
    balance = initial_hrn * 100 + initial_kop
    print(f"[Ініціалізація] Початковий баланс: {hrn_kop_to_str(balance)}")


    a0_insert_card()
    try:
        card_type = int(input("Тип картки (наприклад, 1 або 2): ").strip())
    except ValueError:
        print("a13: Невірний формат типу картки. Картку повернуто.")
        return

    if not a1_recognize_card(card_type):
        return

    a2_prompt_pin()
    tries = MAX_PIN_TRIES
    authed = False
    while tries > 0 and not authed:
        try:
            pin = int(input("PIN: ").strip())
        except ValueError:
            pin = -1
        authed, tries = a3_check_pin(pin, tries)
        if not authed and tries > 0:
            a2_prompt_pin()
    if not authed:
        return  # a12 — блокування

    # a4 — головне меню
    while True:
        choice = a4_menu()
        if choice == "1":
            a5_show_balance(balance)
            # повернення до a4
        elif choice == "2":
            amount = a6_ask_amount()
            if amount <= 0:
                print("Сума має бути додатною.")
                continue
            if a7_has_funds(balance, amount):
                balance = a8_dispense_cash(balance, amount)  # включає корегування і повернення до меню
            else:
                a9_insufficient()
        elif choice == "3":
            a10_goodbye()
            break
        else:
            print("Невірний вибір. Спробуйте ще раз.")


main()
# Out:
# [Ініціалізація] Початковий баланс: 18676.80 грн
# a0: Будь ласка, вставте картку (введіть тип картки цілим числом).
# Тип картки (наприклад, 1 або 2): 2
# a1: Картку розпізнано.
# a2: Введіть PIN-код (ціле число).
# PIN: 1234
# a3: Код вірний.
#
# === a4: Меню ===
# 1) Стан рахунку
# 2) Зняття готівки
# 3) Вихід
# Оберіть операцію (1/2/3): 1
# a5: Стан рахунку: 18676.80 грн
#
# === a4: Меню ===
# 1) Стан рахунку
# 2) Зняття готівки
# 3) Вихід
# Оберіть операцію (1/2/3): 2
# a6: Введіть суму для зняття (грн або грн.коп): 20000
# a9: Недостатньо коштів на рахунку. Повернення до меню.
#
# === a4: Меню ===
# 1) Стан рахунку
# 2) Зняття готівки
# 3) Вихід
# Оберіть операцію (1/2/3): 2
# a6: Введіть суму для зняття (грн або грн.коп): 1000
# a8: Видано готівку: 1000.00 грн
#    Номінали: 1000 грн × 1
#    Новий баланс: 17676.80 грн
#
# === a4: Меню ===
# 1) Стан рахунку
# 2) Зняття готівки
# 3) Вихід
# Оберіть операцію (1/2/3): 3
# a10: Дякуємо! Гарного дня. Картку повернуто.

# %% [markdown]
# У ході виконання лабораторної роботи було реалізовано алгоритм функціонування банкомата у вигляді програми мовою Python. Алгоритм побудований на основі математичної моделі кінцевого автомата, у якій кожен етап роботи банкомата (a0–a13) відповідає окремому стану, а переходи між станами здійснюються залежно від вхідних даних користувача та заданих умов. Такий підхід дозволив формалізувати реальний процес обслуговування картки як послідовність станів із чіткими правилами переходів.
#
# Побудована модель демонструє, як засобами програмування можна реалізувати абстрактні математичні конструкції для опису роботи технічних пристроїв. Використання випадкової ініціалізації балансу відповідає моделюванню невизначених початкових умов, а перевірка коду, типу картки та достатності коштів реалізує логіку розгалужень, властиву математичним моделям типу «автомат із входами та виходами». Отже, виконане завдання підтверджує тісний зв’язок між математичними моделями та їхньою практичною реалізацією у вигляді програмного забезпечення, що є важливим у процесі вивчення моделювання та алгоритмізації.

# %% [markdown]
# 1.5.1. Який вигляд повинні мати фігури Лісажу при раціональному та ірраціональному  співвідношенні частот?
#
#  Фігури Лісажу залежать від співвідношення частот двох гармонічних коливань. Якщо відношення частот є раціональним числом (наприклад, 1:2, 2:3, 3:4), то крива Лісажу має замкнений вигляд і утворює симетричні геометричні фігури (еліпси, вісімки, більш складні замкнені криві). Якщо ж відношення частот є ірраціональним, то траєкторія ніколи не замикається і поступово заповнює всю область прямокутника, утворюючи густий візерунок з ліній.
#
# 1.5.2. Навести приклад стійкої системи рівнянь не менш ніж 3-го порядку та продемонструвати її стійкість за критерієм Михайлова.
#
#  Приклад стійкої системи 3-го порядку: D(p) = p^3 + 4p^2 + 5p + 2. У цій системі всі коефіцієнти додатні, а при підстановці p = jω годограф Михайлова при ω:0→∞ здійснює послідовний обхід усіх квадрантів проти годинникової стрілки. Зміна аргумента arg D(jω) становить 3π/2 = 270°, що відповідає порядку полінома. Таким чином, умова критерію Михайлова виконується, і система є стійкою.
#
# 1.5.3. Чи містить мова Python засоби, за допомогою яких можна задати можливість повторного  вводу коду, без використання стану а11?
#
# Так, у мові Python існують засоби, які дозволяють організувати повторний ввід без використання спеціального стану a11. Це можна зробити за допомогою циклів (while, for) та перевірки умов. Наприклад, у циклі while можна виконувати запит на введення коду доти, поки він не буде правильним або поки не вичерпано кількість спроб. Таким чином, повторний ввід реалізується засобами самої мови програмування, без окремого стану в алгоритмі.
